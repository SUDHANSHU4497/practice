# %% [markdown]
# <a href="https://colab.research.google.com/github/SUDHANSHU4497/practice/blob/main/Data_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
url='/content/drive/MyDrive/dataset/Titanic.csv'

# %%
# Load library
import pandas as pd
# Create URL

# Load data as a dataframe
dataframe = pd.read_csv(url)
# Show first 5 rows
dataframe.head(5)
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
# Show dimensions
dataframe.shape
# Out:
# (1313, 5)

# %%
# Show statistics
dataframe.describe()
# Out:
#               Age     Survived
# count  756.000000  1313.000000
# mean    30.397989     0.342727
# std     14.259049     0.474802
# min      0.170000     0.000000
# 25%     21.000000     0.000000
# 50%     28.000000     0.000000
# 75%     39.000000     1.000000
# max     71.000000     1.000000

# %%
# Select first row
dataframe.iloc[0]
# Out:
# Name        Allen, Miss Elisabeth Walton
# PClass                               1st
# Age                                 29.0
# Sex                               female
# Survived                               1
# Name: 0, dtype: object

# %%
# Select three rows
dataframe.iloc[1:4]
# Out:
#                                             Name PClass   Age     Sex  \
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.0    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
#
#    Survived
# 1         0
# 2         0
# 3         0

# %%
# Set index
dataframe = dataframe.set_index(dataframe['Name'])
# Show row
dataframe.loc['Allen, Miss Elisabeth Walton']
# Out:
# Name        Allen, Miss Elisabeth Walton
# PClass                               1st
# Age                                 29.0
# Sex                               female
# Survived                               1
# Name: Allen, Miss Elisabeth Walton, dtype: object

# %%
# Show top two rows where column 'sex' is 'female'
dataframe[dataframe['Sex'] == 'female'].head(2)
# Out:
#                                                       Name PClass   Age  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton    1st  29.0
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine    1st   2.0
#
#                                  Sex  Survived
# Name
# Allen, Miss Elisabeth Walton  female         1
# Allison, Miss Helen Loraine   female         0

# %%
# Filter rows
dataframe[(dataframe['Sex'] == 'female') & (dataframe['Age'] >= 65)]
# Out:
#                                                                                                  Name  \
# Name
# Crosby, Mrs Edward Gifford (Catherine Elizabeth...  Crosby, Mrs Edward Gifford (Catherine Elizabet...
#
#                                                    PClass   Age     Sex  \
# Name
# Crosby, Mrs Edward Gifford (Catherine Elizabeth...    1st  69.0  female
#
#                                                     Survived
# Name
# Crosby, Mrs Edward Gifford (Catherine Elizabeth...         1
