# %% [markdown]
# <a href="https://colab.research.google.com/github/SUDHANSHU4497/practice/blob/main/data_statistic_understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pima='/content/drive/MyDrive/dataset/pima-indians-diabetes.csv'
headernames = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class'] 
df=pd.read_csv(pima,names=headernames )

# %%
df.head(2)
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0

# %%
df.dtypes
# Out:
# preg       int64
# plas       int64
# pres       int64
# skin       int64
# test       int64
# mass     float64
# pedi     float64
# age        int64
# class      int64
# dtype: object

# %%
df.describe()
# Out:
#              preg        plas        pres        skin        test        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
from pandas import set_option
set_option('display.width',1)
# set_option('precision' ,2)
df.describe()
# Out:
#          preg  \
# count  768.00
# mean     3.85
# std      3.37
# min      0.00
# 25%      1.00
# 50%      3.00
# 75%      6.00
# max     17.00
#
#          plas  \
# count  768.00
# mean   120.89
# std     31.97
# min      0.00
# 25%     99.00
# 50%    117.00
# 75%    140.25
# max    199.00
#
#          pres  \
# count  768.00
# mean    69.11
# std     19.36
# min      0.00
# 25%     62.00
# 50%     72.00
# 75%     80.00
# max    122.00
#
#          skin  \
# count  768.00
# mean    20.54
# std     15.95
# min      0.00
# 25%      0.00
# 50%     23.00
# 75%     32.00
# max     99.00
#
#          test  \
# count  768.00
# mean    79.80
# std    115.24
# min      0.00
# 25%      0.00
# 50%     30.50
# 75%    127.25
# max    846.00
#
#          mass  \
# count  768.00
# mean    31.99
# std      7.88
# min      0.00
# 25%     27.30
# 50%     32.00
# 75%     36.60
# max     67.10
#
#          pedi  \
# count  768.00
# mean     0.47
# std      0.33
# min      0.08
# 25%      0.24
# ...

# %% [markdown]
# ***reviewing class distribution***

# %%
cc=df.groupby('class').size()   #total count for 1 and 0 for class variable
cc
# Out:
# class
# 0    500
# 1    268
# dtype: int64

# %% [markdown]
# **Reviewing Correlation between Attributes **

# %%
correlations = df.corr(method='pearson') 
print(correlations)
# Out:
#        preg  \
# preg   1.00
# plas   0.13
# pres   0.14
# skin  -0.08
# test  -0.07
# mass   0.02
# pedi  -0.03
# age    0.54
# class  0.22
#
#        plas  \
# preg   0.13
# plas   1.00
# pres   0.15
# skin   0.06
# test   0.33
# mass   0.22
# pedi   0.14
# age    0.26
# class  0.47
#
#        pres  \
# preg   0.14
# plas   0.15
# pres   1.00
# skin   0.21
# test   0.09
# mass   0.28
# pedi   0.04
# age    0.24
# class  0.07
#
#        skin  \
# preg  -0.08
# plas   0.06
# pres   0.21
# skin   1.00
# test   0.44
# mass   0.39
# pedi   0.18
# age   -0.11
# class  0.07
#
#        test  \
# preg  -0.07
# plas   0.33
# pres   0.09
# skin   0.44
# test   1.00
# mass   0.20
# pedi   0.19
# age   -0.04
# class  0.13
#
#        mass  \
# preg   0.02
# plas   0.22
# pres   0.28
# skin   0.39
# test   0.20
# mass   1.00
# pedi   0.14
# age    0.04
# class  0.29
#
#        pedi  \
# preg  -0.03
# plas   0.14
# pres   0.04
# skin   0.18
# test   0.19
# mass   0.14
# pedi   1.00
# age    0.03
# ...

# %%
set_option('display.width', 70) 
set_option('precision', 2) 
correlations = df.corr(method='pearson') 
print(correlations)
# Out:
#        preg  plas  pres  skin  test  mass  pedi   age  class
# preg   1.00  0.13  0.14 -0.08 -0.07  0.02 -0.03  0.54   0.22
# plas   0.13  1.00  0.15  0.06  0.33  0.22  0.14  0.26   0.47
# pres   0.14  0.15  1.00  0.21  0.09  0.28  0.04  0.24   0.07
# skin  -0.08  0.06  0.21  1.00  0.44  0.39  0.18 -0.11   0.07
# test  -0.07  0.33  0.09  0.44  1.00  0.20  0.19 -0.04   0.13
# mass   0.02  0.22  0.28  0.39  0.20  1.00  0.14  0.04   0.29
# pedi  -0.03  0.14  0.04  0.18  0.19  0.14  1.00  0.03   0.17
# age    0.54  0.26  0.24 -0.11 -0.04  0.04  0.03  1.00   0.24
# class  0.22  0.47  0.07  0.07  0.13  0.29  0.17  0.24   1.00

# %% [markdown]
# ***REVIEW SKEW OF ATTRIBUTE DISTIBUTION***

# %%
print(df.skew())
# Out:
# preg     0.90
# plas     0.17
# pres    -1.84
# skin     0.11
# test     2.27
# mass    -0.43
# pedi     1.92
# age      1.13
# class    0.64
# dtype: float64
